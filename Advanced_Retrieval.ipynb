# %% [markdown]
# ## Advanced Retrieval Techniques
#
# Notebook walking through evaluating Parent Document Retrieval and Contextual Compression (Rerank)

# %%
import os
from getpass import getpass
from datetime import datetime
os.environ['OPENAI_API_KEY'] = getpass("Enter your OpenAI API key: ")
os.environ["COHERE_API_KEY"] = getpass("Enter your Cohere API Key: ")
os.environ["LANGSMITH_API_KEY"] = getpass("Enter your LangSmith API Key:")
import os
os.environ["LANGCHAIN_TRACING_V2"] = "false" 

def enable_tracing_for_evaluation():
    os.environ["LANGCHAIN_TRACING_V2"] = "true"
    os.environ["LANGCHAIN_PROJECT"] = f"RAG_Evaluation_{datetime.now().strftime('%Y%m%d_%H%M%S')}"

def disable_tracing():
    os.environ["LANGCHAIN_TRACING_V2"] = "false"

# %% [markdown]
# ### Data preparation and retrieval setup for contextual compression

# %%
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import PyMuPDFLoader

path = "data/"
loader = DirectoryLoader(path, glob="*.pdf", loader_cls=PyMuPDFLoader)
docs = loader.load()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=750, chunk_overlap=150)
#trying smaller chunks after baseline evaluation
split_documents = text_splitter.split_documents(docs)
len(split_documents)
# Out:
# 2483

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams

client = QdrantClient(":memory:")

client.create_collection(
    collection_name="Contextual_Compression_Loan_Data",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)

vectorstore = QdrantVectorStore(
    client=client,
    collection_name="Contextual_Compression_Loan_Data",
    embedding=embeddings,
)

vectorstore.add_documents(split_documents)
# Out:
# ['dfcac70cd3934facbe8eb05ecbf127bf',
#  '8f64d3b7e70b49eb890a6355a3ccc290',
#  '6d5f5706cef74784aabff421263fcf72',
#  '2611b60442af4bb5aadd1f06079c4ef7',
#  '12ee4e352f4a49cf8804135df3834dc6',
#  '22725d497d9246398bbbd2dd513abb72',
#  '77b52e01a7604465b1cd2c509a87038b',
#  'd3212ad159fb49dd8b59983df2685f42',
#  '62021972fab6412f803ebae49f31ce4d',
#  'd179c9845a3046098c62efc59d441db0',
#  '938c45928d7146658295195914dcf288',
#  '16668321a9434145b6518c118791bebf',
#  '183f5b395b724e31874fc8c1b033be91',
#  'c4daff477462433caa829ea3c0fe5a61',
#  '84bfc1e168a24c0a9234b8c6df6ffbb1',
#  '1ec585a5239c45938e949baf6a9ed955',
#  '342be892a2fb4049a842ce4798349e24',
#  '45b0c0e581534073b718f6a0099d72e3',
#  'ee056801cc764cd09facb498eb9cd8a0',
#  '81499d4d49f84fe8b4ab982cb5e43fcf',
#  '367a81dc0c6a4e88960eec476f80c50a',
#  '180173d2c00140828f180e2031cf30da',
#  'a65393bdd8ea4f4898f0af3e3c033738',
#  '8ccffa6e8f0d42618a37a2569bda05f2',
#  'dddf7a5eec0c452a94ca841169f44aa9',
#  'c6da496c73724a99a508f2f909703908',
#  'b8dd390c003e4b298d8424029bd7df35',
#  'ffcd5544903b42c79105d2f9fd28db79',
#  'c433f8ff09414cd6a3cf058e658499ca',
#  'cb720558bb564f7c94e5fee448609cf1',
#  'e076239b3f4b436eb3729193ba498359',
#  'ef2e71d8ce7b4ba684010b54dc5bfded',
#  'ff5894574a884959af791c74bda81f16',
#  '206048b86c7f4249ac8738ab765d6569',
#  'e59e1b05361e4a62b0573aa2ec2a8472',
#  '9a69eb90149f471599e182f6a55961c1',
#  '782156615d6945019650f6ab112a0124',
#  '6d8efab723f6496eab89ef821d35ccb4',
#  'ed32847cd8924617b2dafa0716b43e71',
#  '1ecb7ff323ea479c918687227ea5ab0f',
#  'b837e78d0dcc41b08de0a7dacf887165',
#  '583137c6d8e543f9bf4bb394e1712519',
#  'a105d7bc3b49444786b1508062feb932',
#  '32176688d73545208e0229d808796b11',
#  'd5f7c7601c954c21ba163b0431414db1',
#  '9e3bdea1298b40a48ccc340e72d6dbea',
#  '550718b7c95a4ed49c4fb4dad976c576',
#  '040b7ee510f94d1b847c4d9da75fb7dc',
#  '2307bb0a25984c559620e8fad81b5d2c',
#  '37067cd66ee44572a9b3b3d8e488fb41',
#  '7c2d81b230d04994a17f06fb8f512d39',
#  ...]

# %%
retriever = vectorstore.as_retriever(search_kwargs={"k" : 15})
#trying more documents after baseline evaluation

# %%
from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_cohere import CohereRerank

def retrieve_contextual(state):
    compressor = CohereRerank(model="rerank-v3.5", top_n=10)
    compression_retriever = ContextualCompressionRetriever(
        base_compressor=compressor, 
        base_retriever=retriever, 
        search_kwargs={"k": 5}
    )
    retrieved_docs = compression_retriever.invoke(state["question"])
    
    return {"context": retrieved_docs}

# %% [markdown]
# ### Data preparation and retrieval setup for parent document

# %%
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from langchain_text_splitters import RecursiveCharacterTextSplitter
from qdrant_client import QdrantClient, models

parent_docs = docs
child_splitter = RecursiveCharacterTextSplitter(chunk_size=750)

# %%
from langchain_qdrant import QdrantVectorStore

client = QdrantClient(location=":memory:")

client.create_collection(
    collection_name="Parent_Document_Loan_Data",
    vectors_config=models.VectorParams(size=1536, distance=models.Distance.COSINE)
)

parent_document_vectorstore = QdrantVectorStore(
    collection_name="Parent_Document_Loan_Data", embedding=OpenAIEmbeddings(model="text-embedding-3-small"), client=client
)

# %%
store = InMemoryStore()

parent_document_retriever = ParentDocumentRetriever(
    vectorstore = parent_document_vectorstore,
    docstore=store,
    child_splitter=child_splitter,
)

# %%
parent_document_retriever.add_documents(parent_docs, ids=None)

# %%
def retrieve_parent_documents(state):
    try:
        retrieved_docs = parent_document_retriever.invoke(state["question"])
        return {"context": retrieved_docs}
    except Exception as e:
        print(f"Error in retrieve_parent_documents: {e}")
        return {"context": []}

# %%
from langchain.prompts import ChatPromptTemplate

RAG_PROMPT = """\
You are a helpful assistant who answers questions based ONLY on the provided context. 
IMPORTANT: You must NOT use any external knowledge. If the context doesn't contain the answer, say "I don't have enough information in the provided documents to answer this question."

Context:
{context}

Question:
{question}

Answer (use ONLY information from the context above):
"""
#trying more strict prompt after baseline evaluation

rag_prompt = ChatPromptTemplate.from_template(RAG_PROMPT)

# %%
from langchain_openai import ChatOpenAI

openai_chat_model = ChatOpenAI(model="gpt-4.1-nano")

# %%
def generate(state):
  docs_content = "\n\n".join(doc.page_content for doc in state["context"])
  messages = rag_prompt.format_messages(question=state["question"], context=docs_content)
  response = openai_chat_model.invoke(messages)
  return {"response" : response.content}

# %%
from langgraph.graph import START, StateGraph
from typing_extensions import List, TypedDict
from langchain_core.documents import Document

class State(TypedDict):
  question: str
  context: List[Document]
  response: str

# %%
contextual_compression_graph_builder = StateGraph(State).add_sequence([retrieve_contextual, generate])
contextual_compression_graph_builder.add_edge(START, "retrieve_contextual")
contextual_compression_graph = contextual_compression_graph_builder.compile()

# %%
parent_document_graph_builder = StateGraph(State).add_sequence([retrieve_parent_documents, generate])
parent_document_graph_builder.add_edge(START, "retrieve_parent_documents")
parent_document_graph = parent_document_graph_builder.compile()

# %%
from langchain_community.tools.tavily_search import TavilySearchResults

tavily_tool = TavilySearchResults(max_results=5)
#This tool will get the latest news/updates on the bill and the student loan repayment plan

# %%
from backend.main import timeline_tool, complete_form_tool, tool_comparison_tool

tool_belt = [
    tavily_tool,
    timeline_tool,
    complete_form_tool,
    tool_comparison_tool,
]

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4.1", temperature=0)

# %%
model = model.bind_tools(tool_belt)

# %%
from typing import TypedDict, Annotated
from langgraph.graph.message import add_messages
import operator
from langchain_core.messages import HumanMessage, BaseMessage
from langchain_core.documents import Document

class AgentState(TypedDict):
    messages: Annotated[list, add_messages]
    context: List[Document]

# %%
from langgraph.prebuilt import ToolNode

def call_model(state):
    messages = state["messages"]
    response = model.invoke(messages)
    return {
        "messages" : [response],
        "context" : state.get("context", [])
        }


tool_node = ToolNode(tool_belt)

# %%
from langgraph.graph import StateGraph, END

uncompiled_graph = StateGraph(AgentState)

uncompiled_graph.add_node("agent", call_model)
uncompiled_graph.add_node("action", tool_node)

# %%
uncompiled_graph.set_entry_point("agent")

# %%
def should_continue(state):
  last_message = state["messages"][-1]

  if last_message.tool_calls:
    return "action"

  return END

uncompiled_graph.add_conditional_edges(
    "agent",
    should_continue
)

# %%
uncompiled_graph.add_edge("action", "agent")
# Out:
# Adding an edge to a graph that has already been compiled. This will not be reflected in the compiled graph.

# %%
compiled_graph = uncompiled_graph.compile()

# %% [markdown]
# ### Evaluation

# %%
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
generator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4.1-mini"))
generator_embeddings = LangchainEmbeddingsWrapper(OpenAIEmbeddings())

# %%
from ragas.testset import TestsetGenerator

generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
import time

# Add delays between operations
print("Starting generation...")
dataset = generator.generate_with_langchain_docs(docs, testset_size=5)
time.sleep(10)  # Wait 10 seconds
print("Generation complete!")

# Enable tracing only for evaluation
enable_tracing_for_evaluation()
# Run your evaluation
# Then disable tracing
disable_tracing()
# Out:
# Starting generation...
# Applying HeadlinesExtractor:   0%|          | 0/452 [00:00<?, ?it/s]
# Applying HeadlineSplitter:   0%|          | 0/480 [00:00<?, ?it/s]
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# Applying SummaryExtractor:   0%|          | 0/864 [00:00<?, ?it/s]
# Property 'summary' already exists in node '475946'. Skipping!
# Property 'summary' already exists in node '54e73b'. Skipping!
# Property 'summary' already exists in node '50bd02'. Skipping!
# Property 'summary' already exists in node 'e7377c'. Skipping!
# Property 'summary' already exists in node 'cce2b5'. Skipping!
# Property 'summary' already exists in node '4ffefb'. Skipping!
# Property 'summary' already exists in node 'a87fe9'. Skipping!
# Property 'summary' already exists in node '7f37dc'. Skipping!
# Property 'summary' already exists in node '291a33'. Skipping!
# Property 'summary' already exists in node '2e9538'. Skipping!
# Property 'summary' already exists in node '48656a'. Skipping!
# Property 'summary' already exists in node 'a3222b'. Skipping!
# Property 'summary' already exists in node 'bc60f2'. Skipping!
# Property 'summary' already exists in node '531bc1'. Skipping!
# Property 'summary' already exists in node '50a393'. Skipping!
# Property 'summary' already exists in node 'b18b6b'. Skipping!
# Property 'summary' already exists in node 'a6719d'. Skipping!
# Property 'summary' already exists in node '8ca71f'. Skipping!
# Property 'summary' already exists in node 'f5f556'. Skipping!
# Property 'summary' already exists in node '10198c'. Skipping!
# Property 'summary' already exists in node 'bcf572'. Skipping!
# Property 'summary' already exists in node '8066bc'. Skipping!
# Property 'summary' already exists in node '98685e'. Skipping!
# Property 'summary' already exists in node '6b0ee4'. Skipping!
# Property 'summary' already exists in node 'ce9f41'. Skipping!
# Property 'summary' already exists in node '88f91b'. Skipping!
# Property 'summary' already exists in node '3dc99b'. Skipping!
# Property 'summary' already exists in node 'd372f5'. Skipping!
# Property 'summary' already exists in node '11efb8'. Skipping!
# Property 'summary' already exists in node '5e44c4'. Skipping!
# Property 'summary' already exists in node '0c310a'. Skipping!
# Property 'summary' already exists in node '1200e6'. Skipping!
# Property 'summary' already exists in node 'ad98db'. Skipping!
# Property 'summary' already exists in node '5b3228'. Skipping!
# Property 'summary' already exists in node '478963'. Skipping!
# Property 'summary' already exists in node '2f229e'. Skipping!
# Property 'summary' already exists in node '5d63ff'. Skipping!
# Property 'summary' already exists in node '623102'. Skipping!
# Property 'summary' already exists in node 'b219ca'. Skipping!
# Property 'summary' already exists in node 'e2d22e'. Skipping!
# Property 'summary' already exists in node 'cd7980'. Skipping!
# Property 'summary' already exists in node 'e986d8'. Skipping!
# Property 'summary' already exists in node '14bab0'. Skipping!
# Property 'summary' already exists in node '78e3a3'. Skipping!
# Property 'summary' already exists in node 'a34376'. Skipping!
# Property 'summary' already exists in node '8981fe'. Skipping!
# Property 'summary' already exists in node '9ac6cc'. Skipping!
# Property 'summary' already exists in node '406513'. Skipping!
# Property 'summary' already exists in node '36a25d'. Skipping!
# Property 'summary' already exists in node 'ce1fc6'. Skipping!
# Property 'summary' already exists in node 'a855c2'. Skipping!
# Property 'summary' already exists in node 'a1adc3'. Skipping!
# Property 'summary' already exists in node '8f9b0c'. Skipping!
# Property 'summary' already exists in node '1162e9'. Skipping!
# Property 'summary' already exists in node 'fa2ccc'. Skipping!
# Property 'summary' already exists in node 'f792cd'. Skipping!
# Property 'summary' already exists in node '7c63b2'. Skipping!
# Property 'summary' already exists in node '0a329b'. Skipping!
# Property 'summary' already exists in node '470f19'. Skipping!
# Property 'summary' already exists in node 'fe14ef'. Skipping!
# Property 'summary' already exists in node 'a0fad1'. Skipping!
# Property 'summary' already exists in node '0e852d'. Skipping!
# Property 'summary' already exists in node '61d936'. Skipping!
# Property 'summary' already exists in node 'fa3171'. Skipping!
# Property 'summary' already exists in node 'd78a29'. Skipping!
# Property 'summary' already exists in node 'd57101'. Skipping!
# Property 'summary' already exists in node '859e13'. Skipping!
# Property 'summary' already exists in node '9608e4'. Skipping!
# Property 'summary' already exists in node 'a2433f'. Skipping!
# Property 'summary' already exists in node 'e4c688'. Skipping!
# Property 'summary' already exists in node '5a83a6'. Skipping!
# Property 'summary' already exists in node '820df9'. Skipping!
# Property 'summary' already exists in node '5ad50b'. Skipping!
# Property 'summary' already exists in node '277a2e'. Skipping!
# Property 'summary' already exists in node '38cf0c'. Skipping!
# Property 'summary' already exists in node '8e1550'. Skipping!
# Property 'summary' already exists in node 'c59736'. Skipping!
# Property 'summary' already exists in node '747344'. Skipping!
# Property 'summary' already exists in node '19c26c'. Skipping!
# Property 'summary' already exists in node '7945ee'. Skipping!
# Property 'summary' already exists in node 'cb25d3'. Skipping!
# Property 'summary' already exists in node '508180'. Skipping!
# Property 'summary' already exists in node '3f19bb'. Skipping!
# Property 'summary' already exists in node '3f6576'. Skipping!
# Property 'summary' already exists in node 'e6cf55'. Skipping!
# Property 'summary' already exists in node '187da3'. Skipping!
# Property 'summary' already exists in node 'eefc1a'. Skipping!
# Property 'summary' already exists in node 'a219c2'. Skipping!
# Property 'summary' already exists in node 'aee08e'. Skipping!
# Property 'summary' already exists in node 'f27ab2'. Skipping!
# Property 'summary' already exists in node 'b091b7'. Skipping!
# Property 'summary' already exists in node 'a19e84'. Skipping!
# Property 'summary' already exists in node 'fe32e0'. Skipping!
# Property 'summary' already exists in node 'b485cd'. Skipping!
# Property 'summary' already exists in node '902527'. Skipping!
# Property 'summary' already exists in node '36cbe4'. Skipping!
# Property 'summary' already exists in node '500868'. Skipping!
# Property 'summary' already exists in node '9032e6'. Skipping!
# Property 'summary' already exists in node 'fb172e'. Skipping!
# Property 'summary' already exists in node '528cc6'. Skipping!
# Property 'summary' already exists in node '86254d'. Skipping!
# Property 'summary' already exists in node '3639e6'. Skipping!
# Property 'summary' already exists in node '905011'. Skipping!
# Property 'summary' already exists in node 'a503ad'. Skipping!
# Property 'summary' already exists in node '0bd1d2'. Skipping!
# Property 'summary' already exists in node '2642e7'. Skipping!
# Property 'summary' already exists in node '903223'. Skipping!
# Property 'summary' already exists in node 'b8f4d7'. Skipping!
# Property 'summary' already exists in node 'b8391b'. Skipping!
# Property 'summary' already exists in node '1fb951'. Skipping!
# Property 'summary' already exists in node '8cdca5'. Skipping!
# Property 'summary' already exists in node '3ba288'. Skipping!
# Property 'summary' already exists in node '6d5c1e'. Skipping!
# Property 'summary' already exists in node 'd519fe'. Skipping!
# Property 'summary' already exists in node 'fd528c'. Skipping!
# Property 'summary' already exists in node '409db0'. Skipping!
# Property 'summary' already exists in node 'f712ed'. Skipping!
# Property 'summary' already exists in node 'f382bd'. Skipping!
# Property 'summary' already exists in node '33f015'. Skipping!
# Property 'summary' already exists in node '3b9f5a'. Skipping!
# Property 'summary' already exists in node 'a090b4'. Skipping!
# Property 'summary' already exists in node '89915e'. Skipping!
# Property 'summary' already exists in node '93c91c'. Skipping!
# Property 'summary' already exists in node 'e49085'. Skipping!
# Property 'summary' already exists in node '546313'. Skipping!
# Property 'summary' already exists in node 'c2ac96'. Skipping!
# Property 'summary' already exists in node 'f390cf'. Skipping!
# Property 'summary' already exists in node '795484'. Skipping!
# Property 'summary' already exists in node '3d7b83'. Skipping!
# Property 'summary' already exists in node 'e28649'. Skipping!
# Property 'summary' already exists in node '775a3b'. Skipping!
# Property 'summary' already exists in node 'adbb87'. Skipping!
# Property 'summary' already exists in node '537d6a'. Skipping!
# Property 'summary' already exists in node '579251'. Skipping!
# Property 'summary' already exists in node '76b1f9'. Skipping!
# Property 'summary' already exists in node 'c63487'. Skipping!
# Property 'summary' already exists in node '9a6357'. Skipping!
# Property 'summary' already exists in node 'ec05a2'. Skipping!
# Property 'summary' already exists in node 'cac104'. Skipping!
# Property 'summary' already exists in node '01baf9'. Skipping!
# Property 'summary' already exists in node '29240b'. Skipping!
# Property 'summary' already exists in node 'd48dad'. Skipping!
# Property 'summary' already exists in node '1ac922'. Skipping!
# Property 'summary' already exists in node 'cea909'. Skipping!
# Property 'summary' already exists in node 'ca35c1'. Skipping!
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1-mini in organization org-hJkXpnZ3aZ67kTVkL0cgRH2j on tokens per min (TPM): Limit 200000, Used 199080, Requested 1502. Please try again in 174ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Property 'summary' already exists in node '7f175f'. Skipping!
# Property 'summary' already exists in node '6fa145'. Skipping!
# Property 'summary' already exists in node '1af97d'. Skipping!
# Property 'summary' already exists in node 'f04e9b'. Skipping!
# Property 'summary' already exists in node '1c46f0'. Skipping!
# Property 'summary' already exists in node 'f1e13e'. Skipping!
# Property 'summary' already exists in node 'c87e24'. Skipping!
# Property 'summary' already exists in node '9b79aa'. Skipping!
# Property 'summary' already exists in node 'e2f910'. Skipping!
# Property 'summary' already exists in node 'e8f516'. Skipping!
# Property 'summary' already exists in node '352d81'. Skipping!
# Property 'summary' already exists in node '76255d'. Skipping!
# Property 'summary' already exists in node '60ae0f'. Skipping!
# Property 'summary' already exists in node 'ce411e'. Skipping!
# Property 'summary' already exists in node '30d1d8'. Skipping!
# Property 'summary' already exists in node 'cac2ce'. Skipping!
# Property 'summary' already exists in node 'e65519'. Skipping!
# Property 'summary' already exists in node '1a73ff'. Skipping!
# Property 'summary' already exists in node '840360'. Skipping!
# Property 'summary' already exists in node '8f2e7e'. Skipping!
# Property 'summary' already exists in node '3fd914'. Skipping!
# Property 'summary' already exists in node 'f95b94'. Skipping!
# Property 'summary' already exists in node '4c848c'. Skipping!
# Property 'summary' already exists in node 'c2e062'. Skipping!
# Property 'summary' already exists in node 'ad8c67'. Skipping!
# Property 'summary' already exists in node '677c1e'. Skipping!
# Property 'summary' already exists in node 'fb1101'. Skipping!
# Property 'summary' already exists in node 'd73399'. Skipping!
# Property 'summary' already exists in node 'aad4ee'. Skipping!
# Property 'summary' already exists in node 'c33c3a'. Skipping!
# Property 'summary' already exists in node '7fcff1'. Skipping!
# Property 'summary' already exists in node 'f80674'. Skipping!
# Property 'summary' already exists in node 'e496ea'. Skipping!
# Property 'summary' already exists in node '4f1653'. Skipping!
# Applying CustomNodeFilter:   0%|          | 0/83 [00:00<?, ?it/s]
# Node 3d085e2b-707e-4541-9dec-74f5f5a92ad0 does not have a summary. Skipping filtering.
# Node fe7f780f-aea9-40a3-9039-81d65b4a3018 does not have a summary. Skipping filtering.
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/1010 [00:00<?, ?it/s]
# unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# Property 'summary_embedding' already exists in node '54e73b'. Skipping!
# Property 'summary_embedding' already exists in node '50bd02'. Skipping!
# Property 'summary_embedding' already exists in node 'cce2b5'. Skipping!
# Property 'summary_embedding' already exists in node '475946'. Skipping!
# Property 'summary_embedding' already exists in node '291a33'. Skipping!
# Property 'summary_embedding' already exists in node '7f37dc'. Skipping!
# Property 'summary_embedding' already exists in node 'a87fe9'. Skipping!
# Property 'summary_embedding' already exists in node '4ffefb'. Skipping!
# Property 'summary_embedding' already exists in node '10198c'. Skipping!
# Property 'summary_embedding' already exists in node 'bc60f2'. Skipping!
# Property 'summary_embedding' already exists in node 'e7377c'. Skipping!
# Property 'summary_embedding' already exists in node 'b18b6b'. Skipping!
# Property 'summary_embedding' already exists in node 'bcf572'. Skipping!
# Property 'summary_embedding' already exists in node '48656a'. Skipping!
# Property 'summary_embedding' already exists in node '50a393'. Skipping!
# Property 'summary_embedding' already exists in node '531bc1'. Skipping!
# Property 'summary_embedding' already exists in node 'a6719d'. Skipping!
# Property 'summary_embedding' already exists in node 'f5f556'. Skipping!
# Property 'summary_embedding' already exists in node '88f91b'. Skipping!
# Property 'summary_embedding' already exists in node '8ca71f'. Skipping!
# Property 'summary_embedding' already exists in node '8066bc'. Skipping!
# Property 'summary_embedding' already exists in node 'a3222b'. Skipping!
# Property 'summary_embedding' already exists in node 'd372f5'. Skipping!
# Property 'summary_embedding' already exists in node '3dc99b'. Skipping!
# Property 'summary_embedding' already exists in node 'ce9f41'. Skipping!
# Property 'summary_embedding' already exists in node '5e44c4'. Skipping!
# Property 'summary_embedding' already exists in node '6b0ee4'. Skipping!
# Property 'summary_embedding' already exists in node 'ad98db'. Skipping!
# Property 'summary_embedding' already exists in node '1200e6'. Skipping!
# Property 'summary_embedding' already exists in node '98685e'. Skipping!
# Property 'summary_embedding' already exists in node 'e2d22e'. Skipping!
# Property 'summary_embedding' already exists in node '2f229e'. Skipping!
# Property 'summary_embedding' already exists in node 'ea80c1'. Skipping!
# Property 'summary_embedding' already exists in node '2e9538'. Skipping!
# Property 'summary_embedding' already exists in node '478963'. Skipping!
# Property 'summary_embedding' already exists in node '11efb8'. Skipping!
# Property 'summary_embedding' already exists in node 'b219ca'. Skipping!
# Property 'summary_embedding' already exists in node '5b3228'. Skipping!
# Property 'summary_embedding' already exists in node '623102'. Skipping!
# Property 'summary_embedding' already exists in node 'cd7980'. Skipping!
# Property 'summary_embedding' already exists in node '5d63ff'. Skipping!
# Property 'summary_embedding' already exists in node '0c310a'. Skipping!
# Property 'summary_embedding' already exists in node '966b18'. Skipping!
# Property 'summary_embedding' already exists in node '14bab0'. Skipping!
# Property 'summary_embedding' already exists in node '78e3a3'. Skipping!
# Property 'summary_embedding' already exists in node '406513'. Skipping!
# Property 'summary_embedding' already exists in node '8981fe'. Skipping!
# Property 'summary_embedding' already exists in node '9ac6cc'. Skipping!
# Property 'summary_embedding' already exists in node 'e986d8'. Skipping!
# Property 'summary_embedding' already exists in node 'a259ff'. Skipping!
# Property 'summary_embedding' already exists in node '1a41c6'. Skipping!
# Property 'summary_embedding' already exists in node 'f710c8'. Skipping!
# Property 'summary_embedding' already exists in node 'e1acc7'. Skipping!
# Property 'summary_embedding' already exists in node '329760'. Skipping!
# Property 'summary_embedding' already exists in node 'cfb7d0'. Skipping!
# Property 'summary_embedding' already exists in node 'd6c8f6'. Skipping!
# Property 'summary_embedding' already exists in node 'd442eb'. Skipping!
# Property 'summary_embedding' already exists in node 'bf4154'. Skipping!
# Property 'summary_embedding' already exists in node '182244'. Skipping!
# Property 'summary_embedding' already exists in node '577efb'. Skipping!
# Property 'summary_embedding' already exists in node 'a34376'. Skipping!
# Property 'summary_embedding' already exists in node '1ad56f'. Skipping!
# Property 'summary_embedding' already exists in node 'a34b2a'. Skipping!
# Property 'summary_embedding' already exists in node 'f55eef'. Skipping!
# Property 'summary_embedding' already exists in node '319501'. Skipping!
# Property 'summary_embedding' already exists in node 'a4ffbf'. Skipping!
# Property 'summary_embedding' already exists in node '1a394c'. Skipping!
# Property 'summary_embedding' already exists in node '1115fc'. Skipping!
# Property 'summary_embedding' already exists in node 'b32bc2'. Skipping!
# Property 'summary_embedding' already exists in node '5c6f27'. Skipping!
# Property 'summary_embedding' already exists in node 'e019ad'. Skipping!
# Property 'summary_embedding' already exists in node '81d7ba'. Skipping!
# Property 'summary_embedding' already exists in node '5608c4'. Skipping!
# Property 'summary_embedding' already exists in node '9df10c'. Skipping!
# Property 'summary_embedding' already exists in node 'c2db53'. Skipping!
# Property 'summary_embedding' already exists in node '747344'. Skipping!
# Property 'summary_embedding' already exists in node '90a132'. Skipping!
# Property 'summary_embedding' already exists in node '63443d'. Skipping!
# Property 'summary_embedding' already exists in node '6d15e8'. Skipping!
# Property 'summary_embedding' already exists in node '64830c'. Skipping!
# Property 'summary_embedding' already exists in node '5b5562'. Skipping!
# Property 'summary_embedding' already exists in node '86ddba'. Skipping!
# Property 'summary_embedding' already exists in node 'd8f168'. Skipping!
# Property 'summary_embedding' already exists in node 'ce03a5'. Skipping!
# Property 'summary_embedding' already exists in node '21a743'. Skipping!
# Property 'summary_embedding' already exists in node '8dddd7'. Skipping!
# Property 'summary_embedding' already exists in node 'a9eb49'. Skipping!
# Property 'summary_embedding' already exists in node '782440'. Skipping!
# Property 'summary_embedding' already exists in node '76a92e'. Skipping!
# Property 'summary_embedding' already exists in node '5bc97c'. Skipping!
# Property 'summary_embedding' already exists in node 'a01c94'. Skipping!
# Property 'summary_embedding' already exists in node '55d5e6'. Skipping!
# Property 'summary_embedding' already exists in node '687d97'. Skipping!
# Property 'summary_embedding' already exists in node '4563be'. Skipping!
# Property 'summary_embedding' already exists in node '334edb'. Skipping!
# Property 'summary_embedding' already exists in node 'd01af3'. Skipping!
# Property 'summary_embedding' already exists in node '3f7c09'. Skipping!
# Property 'summary_embedding' already exists in node 'e6301d'. Skipping!
# Property 'summary_embedding' already exists in node '28e11e'. Skipping!
# Property 'summary_embedding' already exists in node 'e02961'. Skipping!
# Property 'summary_embedding' already exists in node '128c61'. Skipping!
# Property 'summary_embedding' already exists in node 'a17b04'. Skipping!
# Property 'summary_embedding' already exists in node '9f3a79'. Skipping!
# Property 'summary_embedding' already exists in node 'e32e08'. Skipping!
# Property 'summary_embedding' already exists in node '45cb38'. Skipping!
# Property 'summary_embedding' already exists in node '9ad402'. Skipping!
# Property 'summary_embedding' already exists in node '470b4c'. Skipping!
# Property 'summary_embedding' already exists in node 'a5194e'. Skipping!
# Property 'summary_embedding' already exists in node '2f33f0'. Skipping!
# Property 'summary_embedding' already exists in node 'fb2927'. Skipping!
# Property 'summary_embedding' already exists in node '2018ca'. Skipping!
# Property 'summary_embedding' already exists in node 'deca36'. Skipping!
# Property 'summary_embedding' already exists in node '67e34b'. Skipping!
# Property 'summary_embedding' already exists in node '78ab7c'. Skipping!
# Property 'summary_embedding' already exists in node '738c80'. Skipping!
# Property 'summary_embedding' already exists in node '8b0e89'. Skipping!
# Property 'summary_embedding' already exists in node '234ca2'. Skipping!
# Property 'summary_embedding' already exists in node '11a498'. Skipping!
# Property 'summary_embedding' already exists in node '0d414c'. Skipping!
# Property 'summary_embedding' already exists in node '1eb735'. Skipping!
# Property 'summary_embedding' already exists in node '4ac65e'. Skipping!
# Property 'summary_embedding' already exists in node 'c8a260'. Skipping!
# Property 'summary_embedding' already exists in node '759799'. Skipping!
# Property 'summary_embedding' already exists in node 'eb5e58'. Skipping!
# Property 'summary_embedding' already exists in node '174ee9'. Skipping!
# Property 'summary_embedding' already exists in node '796c1e'. Skipping!
# Property 'summary_embedding' already exists in node '6cef5c'. Skipping!
# Property 'summary_embedding' already exists in node '3ca0da'. Skipping!
# Property 'summary_embedding' already exists in node 'd0c8cd'. Skipping!
# Property 'summary_embedding' already exists in node '0e3478'. Skipping!
# Property 'summary_embedding' already exists in node 'fdafa7'. Skipping!
# Property 'summary_embedding' already exists in node '0150c0'. Skipping!
# Property 'summary_embedding' already exists in node 'ce4b2d'. Skipping!
# Property 'summary_embedding' already exists in node 'c8fa9b'. Skipping!
# Property 'summary_embedding' already exists in node '51680a'. Skipping!
# Property 'summary_embedding' already exists in node 'f5d028'. Skipping!
# Property 'summary_embedding' already exists in node '7cf98b'. Skipping!
# Property 'summary_embedding' already exists in node 'f829db'. Skipping!
# Property 'summary_embedding' already exists in node 'b44133'. Skipping!
# Property 'summary_embedding' already exists in node 'd72005'. Skipping!
# Property 'summary_embedding' already exists in node '8db8c3'. Skipping!
# Property 'summary_embedding' already exists in node '90079c'. Skipping!
# Property 'summary_embedding' already exists in node 'a8e832'. Skipping!
# Property 'summary_embedding' already exists in node '51c823'. Skipping!
# Property 'summary_embedding' already exists in node '488748'. Skipping!
# Property 'summary_embedding' already exists in node 'f76385'. Skipping!
# Property 'summary_embedding' already exists in node '14af9f'. Skipping!
# Property 'summary_embedding' already exists in node '65bdd4'. Skipping!
# Property 'summary_embedding' already exists in node '4b4580'. Skipping!
# Property 'summary_embedding' already exists in node 'dec789'. Skipping!
# Property 'summary_embedding' already exists in node 'fb1b7f'. Skipping!
# Property 'summary_embedding' already exists in node 'acc22c'. Skipping!
# Property 'summary_embedding' already exists in node '96ae54'. Skipping!
# Property 'summary_embedding' already exists in node '2a376c'. Skipping!
# Property 'summary_embedding' already exists in node 'dea0cb'. Skipping!
# Property 'summary_embedding' already exists in node '9a4147'. Skipping!
# Property 'summary_embedding' already exists in node '8c3634'. Skipping!
# Property 'summary_embedding' already exists in node '9262b0'. Skipping!
# Property 'summary_embedding' already exists in node '5b25de'. Skipping!
# Property 'summary_embedding' already exists in node '71c5e4'. Skipping!
# Property 'summary_embedding' already exists in node '3cac6a'. Skipping!
# Property 'summary_embedding' already exists in node 'fc516e'. Skipping!
# Property 'summary_embedding' already exists in node '60f10f'. Skipping!
# Property 'summary_embedding' already exists in node 'c61dbc'. Skipping!
# Property 'summary_embedding' already exists in node 'a0c5f1'. Skipping!
# Property 'summary_embedding' already exists in node '1f635a'. Skipping!
# Property 'summary_embedding' already exists in node '4e2e8d'. Skipping!
# Property 'summary_embedding' already exists in node '5afedb'. Skipping!
# Property 'summary_embedding' already exists in node '3ed038'. Skipping!
# Property 'summary_embedding' already exists in node 'bab16c'. Skipping!
# Property 'summary_embedding' already exists in node '1c5888'. Skipping!
# Property 'summary_embedding' already exists in node '821401'. Skipping!
# Property 'summary_embedding' already exists in node 'ade13f'. Skipping!
# Property 'summary_embedding' already exists in node '9c20ea'. Skipping!
# Property 'summary_embedding' already exists in node '660e51'. Skipping!
# Property 'summary_embedding' already exists in node '0f7210'. Skipping!
# Property 'summary_embedding' already exists in node '0a28ce'. Skipping!
# Property 'summary_embedding' already exists in node 'a7f737'. Skipping!
# Property 'summary_embedding' already exists in node '7f9874'. Skipping!
# Property 'summary_embedding' already exists in node '4f7954'. Skipping!
# Property 'summary_embedding' already exists in node 'bf53ea'. Skipping!
# Property 'summary_embedding' already exists in node '8975d9'. Skipping!
# Property 'summary_embedding' already exists in node 'acd457'. Skipping!
# Property 'summary_embedding' already exists in node 'c94d7c'. Skipping!
# Property 'summary_embedding' already exists in node '4f1653'. Skipping!
# Property 'summary_embedding' already exists in node '983bf2'. Skipping!
# Property 'summary_embedding' already exists in node 'e7a8c4'. Skipping!
# Property 'summary_embedding' already exists in node '67cf81'. Skipping!
# Property 'summary_embedding' already exists in node '4011c1'. Skipping!
# Property 'summary_embedding' already exists in node 'cbb3b0'. Skipping!
# Property 'summary_embedding' already exists in node '030c29'. Skipping!
# Property 'summary_embedding' already exists in node '5b6749'. Skipping!
# Property 'summary_embedding' already exists in node 'ba2ea1'. Skipping!
# Property 'summary_embedding' already exists in node '83d1c6'. Skipping!
# Property 'summary_embedding' already exists in node 'e696a4'. Skipping!
# Property 'summary_embedding' already exists in node '3fd072'. Skipping!
# Property 'summary_embedding' already exists in node '415a06'. Skipping!
# Property 'summary_embedding' already exists in node '7e2537'. Skipping!
# Property 'summary_embedding' already exists in node 'cf0328'. Skipping!
# Property 'summary_embedding' already exists in node '71b8bc'. Skipping!
# Property 'summary_embedding' already exists in node '7503bc'. Skipping!
# Property 'summary_embedding' already exists in node '38f74c'. Skipping!
# Property 'summary_embedding' already exists in node 'db5468'. Skipping!
# Property 'summary_embedding' already exists in node '52694a'. Skipping!
# Property 'summary_embedding' already exists in node 'e77a86'. Skipping!
# Property 'summary_embedding' already exists in node '69869b'. Skipping!
# Property 'summary_embedding' already exists in node '60141c'. Skipping!
# Property 'summary_embedding' already exists in node '0aff38'. Skipping!
# Property 'summary_embedding' already exists in node '4f1685'. Skipping!
# Property 'summary_embedding' already exists in node '6290c1'. Skipping!
# Property 'summary_embedding' already exists in node '32f5f7'. Skipping!
# Property 'summary_embedding' already exists in node '2f2441'. Skipping!
# Property 'summary_embedding' already exists in node 'e283aa'. Skipping!
# Property 'summary_embedding' already exists in node '0cbd83'. Skipping!
# Property 'summary_embedding' already exists in node '4210d8'. Skipping!
# Property 'summary_embedding' already exists in node '1d17e9'. Skipping!
# Property 'summary_embedding' already exists in node 'f6ba2e'. Skipping!
# Property 'summary_embedding' already exists in node '990031'. Skipping!
# Property 'summary_embedding' already exists in node '1392b4'. Skipping!
# Property 'summary_embedding' already exists in node '78de86'. Skipping!
# Property 'summary_embedding' already exists in node '3e3339'. Skipping!
# Property 'summary_embedding' already exists in node 'bd1b05'. Skipping!
# Property 'summary_embedding' already exists in node '929732'. Skipping!
# Property 'summary_embedding' already exists in node 'cbdb13'. Skipping!
# Property 'summary_embedding' already exists in node '8ac58d'. Skipping!
# Property 'summary_embedding' already exists in node '4e0923'. Skipping!
# Property 'summary_embedding' already exists in node 'b8afa6'. Skipping!
# Property 'summary_embedding' already exists in node '1885ea'. Skipping!
# Property 'summary_embedding' already exists in node '270a82'. Skipping!
# Property 'summary_embedding' already exists in node 'c9f2ce'. Skipping!
# Property 'summary_embedding' already exists in node '44e140'. Skipping!
# Property 'summary_embedding' already exists in node '61c937'. Skipping!
# Property 'summary_embedding' already exists in node '026bfa'. Skipping!
# Property 'summary_embedding' already exists in node '3bf7a0'. Skipping!
# Property 'summary_embedding' already exists in node 'f9190f'. Skipping!
# Property 'summary_embedding' already exists in node 'c2dad4'. Skipping!
# Property 'summary_embedding' already exists in node 'fb78d2'. Skipping!
# Property 'summary_embedding' already exists in node '985326'. Skipping!
# Property 'summary_embedding' already exists in node 'a56958'. Skipping!
# Property 'summary_embedding' already exists in node 'dc809c'. Skipping!
# Property 'summary_embedding' already exists in node '2bb397'. Skipping!
# Property 'summary_embedding' already exists in node 'd0e8cc'. Skipping!
# Property 'summary_embedding' already exists in node 'c55e0f'. Skipping!
# Property 'summary_embedding' already exists in node '67a1eb'. Skipping!
# Property 'summary_embedding' already exists in node '752351'. Skipping!
# Property 'summary_embedding' already exists in node '811893'. Skipping!
# Property 'summary_embedding' already exists in node '35f424'. Skipping!
# Property 'summary_embedding' already exists in node '0ebbfe'. Skipping!
# Property 'summary_embedding' already exists in node '7415a7'. Skipping!
# Property 'summary_embedding' already exists in node '20516f'. Skipping!
# Property 'summary_embedding' already exists in node '75391c'. Skipping!
# Property 'summary_embedding' already exists in node '2d391d'. Skipping!
# Property 'summary_embedding' already exists in node '448a58'. Skipping!
# Property 'summary_embedding' already exists in node '335a95'. Skipping!
# Property 'summary_embedding' already exists in node 'b61471'. Skipping!
# Property 'summary_embedding' already exists in node '8f9b0c'. Skipping!
# Property 'summary_embedding' already exists in node 'e0e8d8'. Skipping!
# Property 'summary_embedding' already exists in node '1e450f'. Skipping!
# Property 'summary_embedding' already exists in node '7bd9c5'. Skipping!
# Property 'summary_embedding' already exists in node 'e37995'. Skipping!
# Property 'summary_embedding' already exists in node '51adc0'. Skipping!
# Property 'summary_embedding' already exists in node '795287'. Skipping!
# Property 'summary_embedding' already exists in node 'ac82bf'. Skipping!
# Property 'summary_embedding' already exists in node 'c60e5d'. Skipping!
# Property 'summary_embedding' already exists in node '61d936'. Skipping!
# Property 'summary_embedding' already exists in node '7bc149'. Skipping!
# Property 'summary_embedding' already exists in node '878b93'. Skipping!
# Property 'summary_embedding' already exists in node 'cb3bde'. Skipping!
# Property 'summary_embedding' already exists in node '066713'. Skipping!
# Property 'summary_embedding' already exists in node 'f7bee1'. Skipping!
# Property 'summary_embedding' already exists in node '8118e2'. Skipping!
# Property 'summary_embedding' already exists in node '9f0d22'. Skipping!
# Property 'summary_embedding' already exists in node 'b78c20'. Skipping!
# Property 'summary_embedding' already exists in node '92f913'. Skipping!
# Property 'summary_embedding' already exists in node '4bb5c6'. Skipping!
# Property 'summary_embedding' already exists in node 'e06f57'. Skipping!
# Property 'summary_embedding' already exists in node 'a0b24c'. Skipping!
# Property 'summary_embedding' already exists in node 'a28ac5'. Skipping!
# Property 'summary_embedding' already exists in node '16a018'. Skipping!
# Property 'summary_embedding' already exists in node 'cf633b'. Skipping!
# Property 'summary_embedding' already exists in node '832caa'. Skipping!
# Property 'summary_embedding' already exists in node 'e49085'. Skipping!
# Property 'summary_embedding' already exists in node '115198'. Skipping!
# Property 'summary_embedding' already exists in node '36a25d'. Skipping!
# Property 'summary_embedding' already exists in node '51cb1a'. Skipping!
# Property 'summary_embedding' already exists in node '63cf91'. Skipping!
# Property 'summary_embedding' already exists in node 'c59736'. Skipping!
# Property 'summary_embedding' already exists in node 'a0fad1'. Skipping!
# Property 'summary_embedding' already exists in node 'ce1fc6'. Skipping!
# Property 'summary_embedding' already exists in node 'fa2ccc'. Skipping!
# Property 'summary_embedding' already exists in node '470f19'. Skipping!
# Property 'summary_embedding' already exists in node '1162e9'. Skipping!
# Property 'summary_embedding' already exists in node '7c63b2'. Skipping!
# Property 'summary_embedding' already exists in node '47e243'. Skipping!
# Property 'summary_embedding' already exists in node 'f792cd'. Skipping!
# Property 'summary_embedding' already exists in node '38cf0c'. Skipping!
# Property 'summary_embedding' already exists in node 'a855c2'. Skipping!
# Property 'summary_embedding' already exists in node '0a329b'. Skipping!
# Property 'summary_embedding' already exists in node 'e4c688'. Skipping!
# Property 'summary_embedding' already exists in node 'e6cf55'. Skipping!
# Property 'summary_embedding' already exists in node '277a2e'. Skipping!
# Property 'summary_embedding' already exists in node 'fa3171'. Skipping!
# Property 'summary_embedding' already exists in node 'fe14ef'. Skipping!
# Property 'summary_embedding' already exists in node 'd78a29'. Skipping!
# Property 'summary_embedding' already exists in node '0e852d'. Skipping!
# Property 'summary_embedding' already exists in node '820df9'. Skipping!
# Property 'summary_embedding' already exists in node 'd57101'. Skipping!
# Property 'summary_embedding' already exists in node '859e13'. Skipping!
# Property 'summary_embedding' already exists in node '5a83a6'. Skipping!
# Property 'summary_embedding' already exists in node 'a2433f'. Skipping!
# Property 'summary_embedding' already exists in node 'a1adc3'. Skipping!
# Property 'summary_embedding' already exists in node '9608e4'. Skipping!
# Property 'summary_embedding' already exists in node '5ad50b'. Skipping!
# Property 'summary_embedding' already exists in node '19c26c'. Skipping!
# Property 'summary_embedding' already exists in node '528cc6'. Skipping!
# Property 'summary_embedding' already exists in node 'b091b7'. Skipping!
# Property 'summary_embedding' already exists in node 'cb25d3'. Skipping!
# Property 'summary_embedding' already exists in node '500868'. Skipping!
# Property 'summary_embedding' already exists in node '8e1550'. Skipping!
# Property 'summary_embedding' already exists in node '508180'. Skipping!
# Property 'summary_embedding' already exists in node '187da3'. Skipping!
# Property 'summary_embedding' already exists in node 'a219c2'. Skipping!
# Property 'summary_embedding' already exists in node '3f19bb'. Skipping!
# Property 'summary_embedding' already exists in node '3f6576'. Skipping!
# Property 'summary_embedding' already exists in node '76b1f9'. Skipping!
# Property 'summary_embedding' already exists in node 'f27ab2'. Skipping!
# Property 'summary_embedding' already exists in node '902527'. Skipping!
# Property 'summary_embedding' already exists in node 'fe32e0'. Skipping!
# Property 'summary_embedding' already exists in node 'aee08e'. Skipping!
# Property 'summary_embedding' already exists in node 'eefc1a'. Skipping!
# Property 'summary_embedding' already exists in node '905011'. Skipping!
# Property 'summary_embedding' already exists in node 'a19e84'. Skipping!
# Property 'summary_embedding' already exists in node '7945ee'. Skipping!
# Property 'summary_embedding' already exists in node '2642e7'. Skipping!
# Property 'summary_embedding' already exists in node 'fb172e'. Skipping!
# Property 'summary_embedding' already exists in node '86254d'. Skipping!
# Property 'summary_embedding' already exists in node 'b8391b'. Skipping!
# Property 'summary_embedding' already exists in node 'b485cd'. Skipping!
# Property 'summary_embedding' already exists in node '9032e6'. Skipping!
# Property 'summary_embedding' already exists in node '3639e6'. Skipping!
# Property 'summary_embedding' already exists in node '546313'. Skipping!
# Property 'summary_embedding' already exists in node 'a503ad'. Skipping!
# Property 'summary_embedding' already exists in node 'd519fe'. Skipping!
# Property 'summary_embedding' already exists in node 'f712ed'. Skipping!
# Property 'summary_embedding' already exists in node '903223'. Skipping!
# Property 'summary_embedding' already exists in node '0bd1d2'. Skipping!
# Property 'summary_embedding' already exists in node '8cdca5'. Skipping!
# Property 'summary_embedding' already exists in node '3ba288'. Skipping!
# Property 'summary_embedding' already exists in node '36cbe4'. Skipping!
# Property 'summary_embedding' already exists in node 'b8f4d7'. Skipping!
# Property 'summary_embedding' already exists in node '1fb951'. Skipping!
# Property 'summary_embedding' already exists in node '01baf9'. Skipping!
# Property 'summary_embedding' already exists in node '3b9f5a'. Skipping!
# Property 'summary_embedding' already exists in node 'f382bd'. Skipping!
# Property 'summary_embedding' already exists in node 'e28649'. Skipping!
# Property 'summary_embedding' already exists in node '409db0'. Skipping!
# Property 'summary_embedding' already exists in node 'c63487'. Skipping!
# Property 'summary_embedding' already exists in node '6d5c1e'. Skipping!
# Property 'summary_embedding' already exists in node 'f390cf'. Skipping!
# Property 'summary_embedding' already exists in node '33f015'. Skipping!
# Property 'summary_embedding' already exists in node '93c91c'. Skipping!
# Property 'summary_embedding' already exists in node '89915e'. Skipping!
# Property 'summary_embedding' already exists in node 'fd528c'. Skipping!
# Property 'summary_embedding' already exists in node '795484'. Skipping!
# Property 'summary_embedding' already exists in node '775a3b'. Skipping!
# Property 'summary_embedding' already exists in node '3d7b83'. Skipping!
# Property 'summary_embedding' already exists in node 'ec05a2'. Skipping!
# Property 'summary_embedding' already exists in node 'adbb87'. Skipping!
# Property 'summary_embedding' already exists in node '537d6a'. Skipping!
# Property 'summary_embedding' already exists in node 'c2ac96'. Skipping!
# Property 'summary_embedding' already exists in node '579251'. Skipping!
# Property 'summary_embedding' already exists in node '1ac922'. Skipping!
# Property 'summary_embedding' already exists in node 'e496ea'. Skipping!
# Property 'summary_embedding' already exists in node '9a6357'. Skipping!
# Property 'summary_embedding' already exists in node '76255d'. Skipping!
# Property 'summary_embedding' already exists in node 'ca35c1'. Skipping!
# Property 'summary_embedding' already exists in node 'cea909'. Skipping!
# Property 'summary_embedding' already exists in node 'cac104'. Skipping!
# Property 'summary_embedding' already exists in node 'e8f516'. Skipping!
# Property 'summary_embedding' already exists in node 'c87e24'. Skipping!
# Property 'summary_embedding' already exists in node 'd48dad'. Skipping!
# Property 'summary_embedding' already exists in node 'a090b4'. Skipping!
# Property 'summary_embedding' already exists in node '6fa145'. Skipping!
# Property 'summary_embedding' already exists in node '9b79aa'. Skipping!
# Property 'summary_embedding' already exists in node '7f175f'. Skipping!
# Property 'summary_embedding' already exists in node '29240b'. Skipping!
# Property 'summary_embedding' already exists in node '1af97d'. Skipping!
# Property 'summary_embedding' already exists in node 'f1e13e'. Skipping!
# Property 'summary_embedding' already exists in node 'e2f910'. Skipping!
# Property 'summary_embedding' already exists in node 'ce411e'. Skipping!
# Property 'summary_embedding' already exists in node '352d81'. Skipping!
# Property 'summary_embedding' already exists in node 'f04e9b'. Skipping!
# Property 'summary_embedding' already exists in node 'c2e062'. Skipping!
# Property 'summary_embedding' already exists in node 'e65519'. Skipping!
# Property 'summary_embedding' already exists in node '60ae0f'. Skipping!
# Property 'summary_embedding' already exists in node '7fcff1'. Skipping!
# Property 'summary_embedding' already exists in node '8f2e7e'. Skipping!
# Property 'summary_embedding' already exists in node 'f80674'. Skipping!
# Property 'summary_embedding' already exists in node '1c46f0'. Skipping!
# Property 'summary_embedding' already exists in node 'cac2ce'. Skipping!
# Property 'summary_embedding' already exists in node '30d1d8'. Skipping!
# Property 'summary_embedding' already exists in node 'aad4ee'. Skipping!
# Property 'summary_embedding' already exists in node 'ad8c67'. Skipping!
# Property 'summary_embedding' already exists in node '840360'. Skipping!
# Property 'summary_embedding' already exists in node '677c1e'. Skipping!
# Property 'summary_embedding' already exists in node 'd73399'. Skipping!
# Property 'summary_embedding' already exists in node '4c848c'. Skipping!
# Property 'summary_embedding' already exists in node '3fd914'. Skipping!
# Property 'summary_embedding' already exists in node 'fb1101'. Skipping!
# Property 'summary_embedding' already exists in node 'f95b94'. Skipping!
# Property 'summary_embedding' already exists in node 'c33c3a'. Skipping!
# Property 'summary_embedding' already exists in node '1a73ff'. Skipping!
# Applying [CosineSimilarityBuilder, OverlapScoreBuilder]:   0%|          | 0/2 [00:00<?, ?it/s]
# unable to apply transformation: Node 4fd798d9-22bc-43ee-a9f5-0647526c38df has no summary_embedding
# Generating personas:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating Scenarios:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating Samples:   0%|          | 0/6 [00:00<?, ?it/s]
# Generation complete!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 13
#      10 print("Generation complete!")
#      12 # Enable tracing only for evaluation
# ---> 13 enable_tracing_for_evaluation()
#      14 # Run your evaluation
#      15 # Then disable tracing
#      16 disable_tracing()
#
# Cell In[34], line 13, in enable_tracing_for_evaluation()
#      11 def enable_tracing_for_evaluation():
#      12     os.environ["LANGCHAIN_TRACING_V2"] = "true"
# ---> 13     os.environ["LANGCHAIN_PROJECT"] = f"RAG_Evaluation_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
#
# AttributeError: module 'datetime' has no attribute 'now'

# %%
dataset.to_pandas()
# Out:
#                                           user_input  \
# 0  Could you explain the exceptions to the minimu...
# 1  What is the minmum loan period if a student is...
# 2            how summer 2 work with SAY loan limits?
# 3  What are the key deadlines related to the IRS'...
# 4  Can you explane how the special depreciation a...
# 5  How do the rules for abbreviated loan periods ...
#
#                                   reference_contexts  \
# 0  [2. Nonstandard terms that are substantially e...
# 1  [Minimum Loan Period: Standard Term and SE9W N...
# 2  [Summer terms are generally not considered to ...
# 3  [<1-hop>\n\nProvision: In addition to paid tax...
# 4  [<1-hop>\n\nProvision: This provision makes se...
# 5  [<1-hop>\n\nRules for Abbreviated Loan Periods...
#
#                                            reference  \
# 0  Chapter 7 discusses exceptions to the minimum ...
# 1  For credit-hour programs with standard terms s...
# 2  If the summer term is split into modules like ...
# 3  The IRS is barred from issuing any additional ...
# 4  The special depreciation allowance for qualifi...
# 5  According to Chapter 1, the rules for abbrevia...
#
#                        synthesizer_name
# 0  single_hop_specifc_query_synthesizer
# 1  single_hop_specifc_query_synthesizer
# 2  single_hop_specifc_query_synthesizer
# 3  multi_hop_specific_query_synthesizer
# 4  multi_hop_specific_query_synthesizer
# 5  multi_hop_specific_query_synthesizer

# %%
for test_row in dataset:
  response = contextual_compression_graph.invoke({"question" : test_row.eval_sample.user_input})
  test_row.eval_sample.response = response["response"]
  test_row.eval_sample.retrieved_contexts = [context.page_content for context in response["context"]]

# %%
from ragas import EvaluationDataset
from ragas import evaluate
from ragas.llms import LangchainLLMWrapper
from ragas.metrics import Faithfulness, ResponseRelevancy, ContextEntityRecall, ContextPrecision
from ragas import evaluate, RunConfig

evaluation_dataset = EvaluationDataset.from_pandas(dataset.to_pandas())

evaluator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4.1-mini", max_tokens=8192))

custom_run_config = RunConfig(timeout=500)

result = evaluate(
    dataset=evaluation_dataset,
    metrics=[ContextPrecision(), Faithfulness(), ResponseRelevancy(), ContextEntityRecall()],
    llm=evaluator_llm,
    run_config=custom_run_config
)
result
# Out:
# Evaluating:   0%|          | 0/24 [00:00<?, ?it/s]
# {'context_precision': 0.8454, 'faithfulness': 0.9815, 'answer_relevancy': 0.6391, 'context_entity_recall': 0.5591}

# %%
for test_row in dataset:
  response = parent_document_graph.invoke({"question" : test_row.eval_sample.user_input})
  test_row.eval_sample.response = response["response"]
  test_row.eval_sample.retrieved_contexts = [context.page_content for context in response["context"]]

# %%
from ragas import EvaluationDataset
from ragas import evaluate
from ragas.llms import LangchainLLMWrapper
from ragas.metrics import Faithfulness, ResponseRelevancy, ContextEntityRecall, ContextPrecision
from ragas import evaluate, RunConfig

parent_evaluation_dataset = EvaluationDataset.from_pandas(dataset.to_pandas())

parent_evaluator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4.1-mini", max_tokens=8192))

custom_run_config = RunConfig(timeout=500)

result = evaluate(
    dataset=parent_evaluation_dataset,
    metrics=[ContextPrecision(), Faithfulness(), ResponseRelevancy(), ContextEntityRecall()],
    llm=parent_evaluator_llm,
    run_config=custom_run_config
)
result
# Out:
# Evaluating:   0%|          | 0/24 [00:00<?, ?it/s]
# {'context_precision': 0.9861, 'faithfulness': 0.7325, 'answer_relevancy': 0.6335, 'context_entity_recall': 0.4750}
